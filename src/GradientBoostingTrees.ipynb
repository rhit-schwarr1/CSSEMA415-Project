# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split

df = pd.read_csv("../data/drug_discovery_virtual_screening.csv")
df.head(3)
# Out:
#   compound_id protein_id  molecular_weight      logp  h_bond_donors  \
# 0   CID_00000    PID_361        499.671415  2.487233              1
# 1   CID_00001    PID_165        436.173570  3.283222              3
# 2   CID_00002    PID_168        514.768854       NaN              2
#
#    h_bond_acceptors  rotatable_bonds  polar_surface_area  compound_clogp  \
# 0                 7                4          113.350817        4.050696
# 1                 4                4           71.981132        3.704408
# 2                11               11           83.936307        1.869610
#
#    protein_length  protein_pi  hydrophobicity  binding_site_size  mw_ratio  \
# 0             678    6.019657        0.812534          12.512165  0.736978
# 1             876    6.447408        0.651417          11.538420  0.497915
# 2             658    3.925837        0.633467          13.155702  0.782323
#
#    logp_pi_interaction  binding_affinity  active
# ...

# %%
X = df.drop(columns=["active", "compound_id", "protein_id", "binding_affinity"])
y = df["active"]

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training samples:", X_train.shape[0])
print("Testing samples:", X_test.shape[0])
# Out:
# Training samples: 1600
# Testing samples: 400

# %%
learning_rate = np.logspace(0, 1, num=10)
maxDepth = np.arange(3, 15, 1)
estimators = np.arange(3, 50, 1)
for learning_rate in learning_rate:
    for maxdepth in maxDepth:
        for estimator in estimators:
            gradBoostClassifier = Pipeline(steps=[
                ("imputer", SimpleImputer(strategy="mean")),
                ("scaler",  StandardScaler()),
                ("classifier", GradientBoostingClassifier(learning_rate=learning_rate, n_estimators=estimator,
                    max_depth=maxdepth, random_state=42))
            ])
            gradBoostClassifier.fit(X_train, y_train)
# Out:
#   Cell In[5], line 9
#     ("scaler" = StandardScaler()),
#      ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?
